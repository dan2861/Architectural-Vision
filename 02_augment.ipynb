# %% [markdown]
# # 02_augment.ipynb
#
# **Objective:**
# 1. Remount your Drive and set paths
# 2. Define a deterministic augmentation pipeline (flip, rotate, scale)
# 3. Apply **N_COPY** augmentations per image and save results
# 4. Preview a handful of augmented samples

# %%
# Cell Tag: parameters
# 1. Mount Google Drive and cd into your dataset
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
# Adjust this path if needed
DATA_ROOT = "/content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/train"
os.chdir(DATA_ROOT)
print("Current working dir:", os.getcwd())
# Out:
# Mounted at /content/drive
# Current working dir: /content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/train

# %%
# Cell Tag: parameters
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
from pathlib import Path
import random

# Paths (adjust if your folder name differs)
DATA_ROOT = Path("/content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/train")
AUG_ROOT  = Path("/content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/augmented")

# Aug settings
N_COPY = 3        # how many aug per source image
SEED   = 42

# Prepare
random.seed(SEED)
AUG_ROOT.mkdir(parents=True, exist_ok=True)

print("Training data root:", DATA_ROOT)
print("Augmented output root:", AUG_ROOT)
# Out:
# Mounted at /content/drive
# Training data root: /content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/train
# Augmented output root: /content/drive/My Drive/Colab Notebooks/CPSC 381-581: Machine Learning/Final Project/data/augmented
